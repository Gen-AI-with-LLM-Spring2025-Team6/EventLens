# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
##Scraping Home page - Master Details

# %%
# Home URL
URL = "https://www.thebostoncalendar.com/events?day=12&month=2&week=1&year=2025"

# %%
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}

# %%
# Getting HTML Content
response = requests.get(URL, headers=HEADERS)
    
if response.status_code != 200:
    print(f"Failed to fetch page: {response.status_code}")
# Converting into Soup Object   
soup = BeautifulSoup(response.text, "lxml")

# %%
# In this Page all the different events are under different li component.
events = soup.find_all("li", class_="event")

# %%
event_data = []

# %%
for event in events:
    title_tag = event.find("h3").find("a")
    title = title_tag.get_text(strip=True) if title_tag else "No Title"

    link = title_tag["href"] if title_tag and title_tag.has_attr("href") else "No Link"
    full_link = f"https://www.thebostoncalendar.com{link}" if link.startswith("/") else link

    event_data.append({"Title": title, "Link": full_link})

# %%
df = pd.DataFrame(event_data)

# %%
df
# Out:
#                                                   Title  \
# 0     V for Vault: An Electronic Dance Music Valentines
# 1        Artz Underground Presents: For The Love of RnB
# 2     ¡Miércoles Maravilloso!: free in-person Spanis...
# 3               100 things to do in Boston this weekend
# 4     91 FREE things to do in Boston this week: Feb ...
# ...                                                 ...
# 1194  Après-ski on the Mystic at The Great American ...
# 1195                          Dirty Disney at Lil Chuck
# 1196                      $1 Oysters at Bootleg Special
# 1197       10PM Detention: Standup Comedy and $4 Drinks
# 1198                  fizzy fridays: all pop, all night
#
#                                                    Link
# 0     https://www.thebostoncalendar.com/events/v-for...
# 1     https://www.thebostoncalendar.com/events/artz-...
# 2     https://www.thebostoncalendar.com/events/mierc...
# 3     https://www.thebostoncalendar.com/events/100-t...
# 4     https://www.thebostoncalendar.com/events/91-fr...
# ...                                                 ...
# 1194  https://www.thebostoncalendar.com/events/apres...
# 1195  https://www.thebostoncalendar.com/events/dirty...
# 1196  https://www.thebostoncalendar.com/events/1-oys...
# 1197  https://www.thebostoncalendar.com/events/late-...
# 1198  https://www.thebostoncalendar.com/events/fizzy...
#
# [1199 rows x 2 columns]

# %% [markdown]
# ### Now from the event list we have to scrape through all individual events page to extract specific event related information

# %%
event_list=[]

# %%
# To retrieve information for each Event Link
for index, row in df.iterrows():
    EVENT_URL = row["Link"]
    
    # To get the HTML content for each link
    response = requests.get(EVENT_URL, headers=HEADERS)

    
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "lxml")

        # To Extract event title
        title_tag = soup.find("h1", itemprop="name")
        title = title_tag.get_text(strip=True) if title_tag else "No Title"

        # To Extract event image URL
        image_tag = soup.find("a", class_="zoom_in")
        image_url = image_tag["href"] if image_tag and image_tag.has_attr("href") else "No Image"

        # To Extract event time
        start_time_tag = soup.find("span", id="startdate", itemprop="startDate")
        end_time_tag = soup.find("span", id="startdate", itemprop="endDate")
        start_time = start_time_tag["content"] if start_time_tag and start_time_tag.has_attr("content") else "No Start Time"
        end_time = end_time_tag["content"] if end_time_tag and end_time_tag.has_attr("content") else "No End Time"

        # To Extract event location
        location_name_tag = soup.find("span", itemprop="name")
        street_address_tag = soup.find("span", itemprop="streetAddress")
        city_tag = soup.find("span", itemprop="addressLocality")
        state_tag = soup.find("span", itemprop="addressRegion")
        postal_code_tag = soup.find("span", itemprop="postalCode")

        location_name = location_name_tag.get_text(strip=True) if location_name_tag else "No Location Name"
        street_address = street_address_tag.get_text(strip=True) if street_address_tag else "No Street Address"
        city = city_tag.get_text(strip=True) if city_tag else "No City"
        state = state_tag.get_text(strip=True) if state_tag else "No State"
        postal_code = postal_code_tag.get_text(strip=True) if postal_code_tag else "No Postal Code"
        full_address = f"{street_address}, {city}, {state} {postal_code}"

        # To Extract event categories
        categories_tag = soup.find("b", string="Categories:")
        categories = categories_tag.find_next_sibling(string=True).strip() if categories_tag else "No Categories"

        # To Extract event admission details
        admission_tag = soup.find("b", string="Admission:")
        admission = admission_tag.find_next_sibling("span").get_text(strip=True) if admission_tag else "No Admission Info"

        # To Extract event description
        description_tag = soup.find("div", id="event_description")
        description = description_tag.get_text(strip=True) if description_tag else "No Description"

        # To Check if any link in the description points to the same site and skip if found
        if description_tag:
            links = description_tag.find_all("a", href=True)
            for link in links:
                if "https://www.thebostoncalendar.com/events/" in link["href"]:
                    continue  # Skip this event if such a link is found


        event_data = {
            "Title": title,
            "Image URL": image_url,
            "Start Time": start_time,
            "End Time": end_time,
            "Location": location_name,
            "Full Address": full_address,
            "Categories": categories,
            "Admission": admission,
            "Description": description,
            "Event URL": EVENT_URL
        }

        event_list.append(event_data)

# %%
# Converting List into DataFrame
df_events = pd.DataFrame(event_list)

# %%
df_events
# Out:
#                                                   Title  \
# 0     V for Vault: An Electronic Dance Music Valentines
# 1        Artz Underground Presents: For The Love of RnB
# 2     ¡Miércoles Maravilloso!: free in-person Spanis...
# 3               100 things to do in Boston this weekend
# 4     91 FREE things to do in Boston this week: Feb ...
# ...                                                 ...
# 1194  Après-ski on the Mystic at The Great American ...
# 1195                          Dirty Disney at Lil Chuck
# 1196                      $1 Oysters at Bootleg Special
# 1197       10PM Detention: Standup Comedy and $4 Drinks
# 1198                  fizzy fridays: all pop, all night
#
#                                               Image URL  \
# 0     https://media.thebostoncalendar.com/images/q_a...
# 1     https://media.thebostoncalendar.com/images/q_a...
# 2                                              No Image
# 3     https://media.thebostoncalendar.com/images/q_a...
# 4     https://media.thebostoncalendar.com/images/q_a...
# ...                                                 ...
# 1194  https://media.thebostoncalendar.com/images/q_a...
# 1195  https://media.thebostoncalendar.com/images/q_a...
# 1196  https://media.thebostoncalendar.com/images/q_a...
# 1197  https://media.thebostoncalendar.com/images/q_a...
# 1198  https://media.thebostoncalendar.com/images/q_a...
#
#                   Start Time                End Time  \
# 0      2025-02-14 7:00pm EST   2025-02-15 1:00am EST
# 1      2025-02-15 7:00pm EST  2025-02-16 12:30am EST
# 2      2025-02-19 7:15pm EST   2025-02-19 8:15pm EST
# 3      2025-02-14 7:00am EST  2025-02-17 11:00pm EST
# 4      2025-02-10 7:00am EST  2025-02-17 11:00pm EST
# ...                      ...                     ...
# 1194   2025-02-21 8:00pm EST  2025-02-22 12:00am EST
# 1195   2025-02-21 9:30pm EST  2025-02-21 11:00pm EST
# 1196  2025-02-21 10:00pm EST   2025-02-23 1:00am EST
# 1197  2025-02-21 10:00pm EST  2025-02-21 11:30pm EST
# 1198  2025-02-21 10:00pm EST   2025-02-22 2:00am EST
#
#                                  Location  \
# 0          The Neal Rantoul Vault Theater
# 1          The Neal Rantoul Vault Theater
# 2     Boston Area Spanish Exchange (BASE)
# 3                                  Boston
# 4                                  Boston
# ...                                   ...
# 1194         The Great American Beer Hall
# 1195  Lil Chuck  at the Charles Playhouse
# 1196                      Bootleg Special
# 1197                    Goofs Comedy Club
# 1198                    The Turing Tavern
#
#                                    Full Address  \
# 0               25 Exchange St., Lynn, MA 01901
# 1               25 Exchange St., Lynn, MA 01901
# 2                101 Arch St., Boston, MA 02110
# 3                Surrounding areas, Boston, MA
# 4                Surrounding areas, Boston, MA
# ...                                         ...
# 1194          142 Mystic Ave, Medford, MA 02155
# 1195      74 Warrenton Street, Boston, MA 02116
# 1196            400 Tremont Street, Boston, MA
# 1197  432 McGrath Highway, Somerville, MA 02143
# 1198     1281 Cambridge St, Cambridge, MA 02139
#
#                                              Categories Admission  \
# 0                        Music, Nightlife, Party, Shows       $15
# 1                       Drinks, Music, Nightlife, Shows       $20
# 2                            Classes, Date Idea, Meetup      FREE
# 3     Animals, Art, Business & Professional, Classes...   $Varies
# 4     Animals, Art, Business & Professional, Classes...      FREE
# ...                                                 ...       ...
# 1194                  Drinks, Nightlife, Outside, Party     $5.00
# 1195      Date Idea, Drinks, Good for Groups, Nightlife       $30
# 1196                                    Date Idea, Food       $1+
# 1197  Accessible Spots, Date Idea, Drinks, Good for ...    $16-22
# 1198                   Drinks, LGBTQ+, Music, Nightlife      FREE
#
#                                             Description  \
# 0     V for Vault: An Electronic Dance Music Valenti...
# 1     Join us For The Love of RnB on Saturday, Febru...
# 2     ¡Miércoles Maravilloso!Free open-level Spanish...
# 3     Celebrate Valentine’s Day weekend and Presiden...
# 4     Happy week of love! It’s time to celebrate our...
# ...                                                 ...
# 1194  Après-ski on the MysticFebruary 21, 2025 8:00 ...
# 1195  Disney adults rejoice! We're back, baby! Revis...
# 1196  Enjoy a late night special of $1 oysters at 10...
# 1197  Every weekend, we bring our favorite headliner...
# 1198  join DJ Frazzo every Friday night 10pm–close 🪩...
#
#                                               Event URL
# 0     https://www.thebostoncalendar.com/events/v-for...
# 1     https://www.thebostoncalendar.com/events/artz-...
# 2     https://www.thebostoncalendar.com/events/mierc...
# 3     https://www.thebostoncalendar.com/events/100-t...
# 4     https://www.thebostoncalendar.com/events/91-fr...
# ...                                                 ...
# 1194  https://www.thebostoncalendar.com/events/apres...
# 1195  https://www.thebostoncalendar.com/events/dirty...
# 1196  https://www.thebostoncalendar.com/events/1-oys...
# 1197  https://www.thebostoncalendar.com/events/late-...
# 1198  https://www.thebostoncalendar.com/events/fizzy...
#
# [1199 rows x 10 columns]

# %%
df_events.columns
# Out:
# Index(['Title', 'Image URL', 'Start Time', 'End Time', 'Location',
#        'Full Address', 'Categories', 'Admission', 'Description', 'Event URL'],
#       dtype='object')

# %% [markdown]
# ### Now Let's Load the data into Snowflake

# %%
# Snowflake Credentials
SNOWFLAKE_ACCOUNT=''
SNOWFLAKE_USER=''
SNOWFLAKE_PASSWORD=''
SNOWFLAKE_DATABASE=''
SNOWFLAKE_SCHEMA=''
SNOWFLAKE_WAREHOUSE=''
SNOWFLAKE_ROLE=''

# %%
import snowflake.connector


conn = snowflake.connector.connect(
    user=SNOWFLAKE_USER,
    password=SNOWFLAKE_PASSWORD,
    account=SNOWFLAKE_ACCOUNT, 
    warehouse=SNOWFLAKE_WAREHOUSE,
    database=SNOWFLAKE_DATABASE,
    schema=SNOWFLAKE_SCHEMA,
    role=SNOWFLAKE_ROLE,
    client_session_keep_alive=True
)


cursor = conn.cursor()

# %%
df_events = df_events.rename(columns={
    "Title":"Event_Title",
    "Image URL": "Image_URL",
    "Start Time": "Start_Time",
    "End Time": "End_Time",
    "Full Address": "Full_Address",
    "Admission": "Admission",
    "Event URL": "Event_URL"
})

# %%
insert_query = """
INSERT INTO STAGING.BOSTON_CALENDAR_EVENTS_DETAILS 
(Event_Title, Image_URL, Start_Time, End_Time, Location, Full_Address, Categories, Admission, Description, Event_URL)
VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
"""

# %%
data_to_insert = [tuple(row) for row in df_events.itertuples(index=False, name=None)]

# %%
cursor.executemany(insert_query, data_to_insert)

conn.commit()
print(f"Inserted {len(data_to_insert)} records into Snowflake.")

cursor.close()
conn.close()
# Out:
# Inserted 1199 records into Snowflake.
